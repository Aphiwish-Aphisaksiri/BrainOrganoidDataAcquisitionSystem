# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft, fftfreq

# Load the HDF5 file
file_path = r'filtereddatarecord\record_20250219_140035_00253800.h5'
with h5py.File(file_path, 'r') as file:
    # Extract the datasets
    raw_data = file['raw_data'][:]
    filtered_data = file['filtered_data'][:]

# Sampling rate
fs = 8000  # Adjust this value based on your configuration

# Perform FFT on raw data
n_raw = raw_data.shape[0]
yf_raw = fft(raw_data, axis=0)
xf_raw = fftfreq(n_raw, 1 / fs)[:n_raw // 2]

# Perform FFT on filtered data
n_filtered = filtered_data.shape[0]
yf_filtered = fft(filtered_data, axis=0)
xf_filtered = fftfreq(n_filtered, 1 / fs)[:n_filtered // 2]

# Plot the FFT result for raw data
plt.figure(figsize=(12, 6))
for i in range(raw_data.shape[1]):
    plt.plot(xf_raw, 2.0 / n_raw * np.abs(yf_raw[:n_raw // 2, i]), label=f'Channel {i + 1}')
plt.title('FFT of Raw Data')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()

# Plot the FFT result for filtered data
plt.figure(figsize=(12, 6))
for i in range(filtered_data.shape[1]):
    plt.plot(xf_filtered, 2.0 / n_filtered * np.abs(yf_filtered[:n_filtered // 2, i]), label=f'Channel {i + 1}')
plt.title('FFT of Filtered Data')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 8
#       6 # Load the HDF5 file
#       7 file_path = r'filtereddatarecord/record_20250217_161243_00253800.h5'
# ----> 8 with h5py.File(file_path, 'r') as file:
#       9     # Extract the datasets
#      10     raw_data = file['raw_data'][:]
#      11     filtered_data = file['filtered_data'][:]
#
# File c:\Users\nealk\miniconda3\envs\brain-knob\Lib\site-packages\h5py\_hl\files.py:561, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     552     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
# ...
